# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Lets first read the data by using read_csv function and convert this data into a dataframe.

# %%
reliance_df = pd.read_csv('RELIANCE.csv')
reliance_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-08-19  2141.000000  2154.000000  2121.350098  2131.550049
# 1    2020-08-20  2120.000000  2123.899902  2088.000000  2097.050049
# 2    2020-08-21  2118.000000  2122.000000  2077.000000  2081.850098
# 3    2020-08-24  2091.399902  2104.500000  2070.500000  2095.750000
# 4    2020-08-25  2106.000000  2111.300049  2078.000000  2082.100098
# ..          ...          ...          ...          ...          ...
# 245  2021-08-12  2124.899902  2126.199951  2105.000000  2110.500000
# 246  2021-08-13  2117.300049  2149.899902  2108.949951  2145.649902
# 247  2021-08-16  2149.350098  2203.000000  2128.149902  2173.500000
# 248  2021-08-17  2168.850098  2185.199951  2147.850098  2164.250000
# 249  2021-08-18  2174.000000  2186.800049  2152.600098  2172.649902
#
#        Adj Close      Volume
# 0    2124.715088  15731396.0
# 1    2090.325684  10401212.0
# 2    2075.174316  11667129.0
# 3    2089.029785  15098991.0
# 4    2075.423584   8947563.0
# ..           ...         ...
# 245  2110.500000   3755507.0
# 246  2145.649902   5898384.0
# 247  2173.500000  10123204.0
# 248  2164.250000   5841743.0
# 249  2172.649902   4650008.0
#
# [250 rows x 7 columns]

# %%
#Lets check no. of rows and col in dataset

reliance_df.shape
# Out:
# (250, 7)

# %% [markdown]
# So it seems their are 15 col and 252 rows in reliance dataframe.
#
# Now lets check the basic information about the data.

# %%
#info() function gives overall information about the data.

reliance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       250 non-null    object
#  1   Open       249 non-null    float64
#  2   High       249 non-null    float64
#  3   Low        249 non-null    float64
#  4   Close      249 non-null    float64
#  5   Adj Close  249 non-null    float64
#  6   Volume     249 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.8+ KB

# %%
reliance_df.Date
# Out:
# 0      2020-08-19
# 1      2020-08-20
# 2      2020-08-21
# 3      2020-08-24
# 4      2020-08-25
#           ...
# 245    2021-08-12
# 246    2021-08-13
# 247    2021-08-16
# 248    2021-08-17
# 249    2021-08-18
# Name: Date, Length: 250, dtype: object

# %% [markdown]
# The Date column has datatype object lets change it to datetime datatype.

# %%
reliance_df['Date'] = pd.to_datetime(reliance_df.Date)

# %%
reliance_df.Date
# Out:
# 0     2020-08-19
# 1     2020-08-20
# 2     2020-08-21
# 3     2020-08-24
# 4     2020-08-25
#          ...
# 245   2021-08-12
# 246   2021-08-13
# 247   2021-08-16
# 248   2021-08-17
# 249   2021-08-18
# Name: Date, Length: 250, dtype: datetime64[ns]

# %% [markdown]
# The date column datatype has changed now its easy to access it. lets make different parts of Date column in different columns.

# %%
reliance_df['month'] = pd.DatetimeIndex(reliance_df.Date).month
reliance_df['day'] = pd.DatetimeIndex(reliance_df.Date).day
reliance_df['weekday'] = pd.DatetimeIndex(reliance_df.Date).weekday
reliance_df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-08-19  2141.000000  2154.000000  2121.350098  2131.550049
# 1   2020-08-20  2120.000000  2123.899902  2088.000000  2097.050049
# 2   2020-08-21  2118.000000  2122.000000  2077.000000  2081.850098
# 3   2020-08-24  2091.399902  2104.500000  2070.500000  2095.750000
# 4   2020-08-25  2106.000000  2111.300049  2078.000000  2082.100098
# ..         ...          ...          ...          ...          ...
# 245 2021-08-12  2124.899902  2126.199951  2105.000000  2110.500000
# 246 2021-08-13  2117.300049  2149.899902  2108.949951  2145.649902
# 247 2021-08-16  2149.350098  2203.000000  2128.149902  2173.500000
# 248 2021-08-17  2168.850098  2185.199951  2147.850098  2164.250000
# 249 2021-08-18  2174.000000  2186.800049  2152.600098  2172.649902
#
#        Adj Close      Volume  month  day  weekday
# 0    2124.715088  15731396.0      8   19        2
# 1    2090.325684  10401212.0      8   20        3
# 2    2075.174316  11667129.0      8   21        4
# 3    2089.029785  15098991.0      8   24        0
# 4    2075.423584   8947563.0      8   25        1
# ..           ...         ...    ...  ...      ...
# 245  2110.500000   3755507.0      8   12        3
# 246  2145.649902   5898384.0      8   13        4
# 247  2173.500000  10123204.0      8   16        0
# 248  2164.250000   5841743.0      8   17        1
# 249  2172.649902   4650008.0      8   18        2
#
# [250 rows x 10 columns]

# %% [markdown]
# We have added month, day, weekday columns in dataframe.

# %%
# columns function gives all the columns in the data.

reliance_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'month',
#        'day', 'weekday'],
#       dtype='object')

# %%
#lets just check some top 10 values

reliance_df.head(10)
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2020-08-19  2141.000000  2154.000000  2121.350098  2131.550049  2124.715088
# 1 2020-08-20  2120.000000  2123.899902  2088.000000  2097.050049  2090.325684
# 2 2020-08-21  2118.000000  2122.000000  2077.000000  2081.850098  2075.174316
# 3 2020-08-24  2091.399902  2104.500000  2070.500000  2095.750000  2089.029785
# 4 2020-08-25  2106.000000  2111.300049  2078.000000  2082.100098  2075.423584
# 5 2020-08-26  2085.000000  2147.949951  2047.000000  2137.300049  2130.446533
# 6 2020-08-27  2148.000000  2150.000000  2103.250000  2110.600098  2103.832275
# 7 2020-08-28  2120.000000  2132.899902  2106.250000  2116.149902  2109.364258
# 8 2020-08-31  2174.000000  2174.000000  2060.350098  2080.699951  2074.028076
# 9 2020-09-01  2100.000000  2122.399902  2062.399902  2087.250000  2080.556885
#
#        Volume  month  day  weekday
# 0  15731396.0      8   19        2
# 1  10401212.0      8   20        3
# 2  11667129.0      8   21        4
# 3  15098991.0      8   24        0
# 4   8947563.0      8   25        1
# 5  27630190.0      8   26        2
# 6  12961252.0      8   27        3
# 7  12537520.0      8   28        4
# 8  28648125.0      8   31        0
# 9  17821397.0      9    1        1

# %%
 reliance_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   249.000000   249.000000   249.000000   249.000000   249.000000
# mean   2068.014859  2089.614047  2040.812858  2062.776310  2057.475665
# std     110.235282   111.434759   108.422569   109.656764   110.108616
# min    1837.000000  1905.000000  1830.000000  1841.949951  1836.043579
# 25%    1980.000000  1997.199951  1960.000000  1976.099976  1969.763428
# 50%    2071.000000  2089.800049  2035.099976  2055.699951  2053.250000
# 75%    2136.449951  2153.550049  2104.250000  2134.250000  2130.446533
# max    2325.000000  2369.350098  2310.550049  2324.550049  2317.096191
#
#              Volume       month         day     weekday
# count  2.490000e+02  250.000000  250.000000  250.000000
# mean   1.169959e+07    6.584000   15.496000    2.008000
# std    7.600158e+06    3.444766    8.767981    1.419859
# min    3.099956e+06    1.000000    1.000000    0.000000
# 25%    6.821015e+06    4.000000    8.000000    1.000000
# 50%    9.591456e+06    7.000000   15.500000    2.000000
# 75%    1.414742e+07    9.750000   23.000000    3.000000
# max    6.475046e+07   12.000000   31.000000    5.000000

# %% [markdown]
# # Exploratory Analysis and Visualization
# In this, we'll do some visualization using some plots, charts in order to make some exploratory analysis.
#
# Let's begin by importingmatplotlib.pyplot and seaborn.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [raw]
# # 1. What was the maximum highest value of Reliance stock in the year 2020 ?

# %%
reliance_df_high = reliance_df.sort_values(by= 'High', ascending=False).head(10)
reliance_df_high
# Out:
#          Date         Open         High          Low        Close  \
# 20 2020-09-16  2320.000000  2369.350098  2310.550049  2324.550049
# 18 2020-09-14  2325.000000  2360.000000  2282.000000  2302.550049
# 16 2020-09-10  2183.100098  2344.949951  2175.350098  2314.000000
# 17 2020-09-11  2312.000000  2337.850098  2287.100098  2319.750000
# 23 2020-09-21  2300.000000  2336.000000  2247.350098  2255.850098
# 21 2020-09-17  2320.000000  2333.699951  2291.850098  2298.750000
# 19 2020-09-15  2311.949951  2325.750000  2288.149902  2318.850098
# 22 2020-09-18  2314.250000  2319.449951  2276.550049  2305.699951
# 34 2020-10-07  2235.000000  2309.000000  2220.000000  2257.500000
# 39 2020-10-14  2278.899902  2304.000000  2268.500000  2287.500000
#
#       Adj Close      Volume  month  day  weekday
# 20  2317.096191  15668979.0      9   16        2
# 18  2295.166748  20335273.0      9   14        0
# 16  2306.579834  64750460.0      9   10        3
# 17  2312.311523  27445768.0      9   11        4
# 23  2248.616455  15519031.0      9   21        0
# 21  2291.378906  11919927.0      9   17        3
# 19  2311.414551  12542824.0      9   15        1
# 22  2298.306396  15264068.0      9   18        4
# 34  2250.260986  24538346.0     10    7        2
# 39  2280.164795  12341434.0     10   14        2

# %%
sns.barplot(reliance_df.month, reliance_df.High);
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It seems that in the month of september and october the stocks value was high which was 2369.

# %% [markdown]
# # 2. What was the lowest close in the year 2020 of the stocks ?

# %%
reliance_df_close = reliance_df.sort_values(by='Close', ascending=True).head(10)
reliance_df_close
# Out:
#           Date         Open         High          Low        Close  \
# 113 2021-01-29  1894.300049  1913.099976  1830.000000  1841.949951
# 53  2020-11-03  1890.000000  1909.000000  1835.099976  1850.400024
# 112 2021-01-28  1880.150024  1923.300049  1870.000000  1876.550049
# 52  2020-11-02  2027.000000  2027.000000  1859.150024  1877.449951
# 111 2021-01-27  1925.000000  1925.000000  1888.000000  1895.000000
# 114 2021-02-01  1859.400024  1905.000000  1848.000000  1895.300049
# 100 2021-01-11  1938.800049  1938.800049  1892.500000  1897.250000
# 66  2020-11-20  1975.000000  1983.800049  1895.000000  1899.500000
# 166 2021-04-20  1910.500000  1919.000000  1890.449951  1901.150024
# 165 2021-04-19  1904.000000  1916.400024  1890.000000  1901.699951
#
#        Adj Close      Volume  month  day  weekday
# 113  1836.043579  20173258.0      1   29        4
# 53   1844.466553  40931170.0     11    3        1
# 112  1870.532715  15722291.0      1   28        3
# 52   1871.429688  45857806.0     11    2        0
# 111  1888.923462  19553809.0      1   27        2
# 114  1889.222534  15774504.0      2    1        0
# 100  1891.166260  15371556.0      1   11        0
# 66   1893.409058  26522972.0     11   20        4
# 166  1895.053833   7939490.0      4   20        1
# 165  1895.601929   8527967.0      4   19        0

# %%
sns.histplot(reliance_df['Close']);

# %% [markdown]
# # 3. What was the turnover in the month of september ?

# %%
# lets extract september month data
reliance_df_september = reliance_df[reliance_df.month == 9]

# data of september month turnover
reliance_df_turnoversept = reliance_df_september['Volume']

# sum of turnover in september
reliance_df_turntotal = reliance_df_turnoversept.sum()
reliance_df_turntotal
# Out:
# 378761955.0

# %%
plt.title('Turnover in September')
plt.plot(reliance_df_turnoversept);

# %% [markdown]
# # 4. What was the count of trade happened in Reliance Shares 2020 ?

# %%
reliance_df_trade = reliance_df.High
reliance_df_tradecount = reliance_df_trade.sum()
reliance_df_tradecount
# Out:
# 520313.89781600004

# %%
sns.barplot(reliance_df.month, reliance_df.High);
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It seems the trade during the month of september, Octomber were high as compared to other months.

# %% [markdown]
# # 5. What was the volume of trades in each month ?

# %%
plt.title('Volume of Trades in Each month')
sns.barplot(reliance_df.month, reliance_df.Volume);
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 6. What was the highest opening value of Reliance share ?

# %%
reliance_df_open = reliance_df.sort_values(by='Open', ascending=False).head(10)
reliance_df_open
# Out:
#          Date         Open         High          Low        Close  \
# 18 2020-09-14  2325.000000  2360.000000  2282.000000  2302.550049
# 21 2020-09-17  2320.000000  2333.699951  2291.850098  2298.750000
# 20 2020-09-16  2320.000000  2369.350098  2310.550049  2324.550049
# 22 2020-09-18  2314.250000  2319.449951  2276.550049  2305.699951
# 17 2020-09-11  2312.000000  2337.850098  2287.100098  2319.750000
# 19 2020-09-15  2311.949951  2325.750000  2288.149902  2318.850098
# 23 2020-09-21  2300.000000  2336.000000  2247.350098  2255.850098
# 40 2020-10-15  2290.000000  2290.000000  2195.000000  2206.500000
# 39 2020-10-14  2278.899902  2304.000000  2268.500000  2287.500000
# 24 2020-09-22  2277.000000  2277.000000  2201.550049  2211.149902
#
#       Adj Close      Volume  month  day  weekday
# 18  2295.166748  20335273.0      9   14        0
# 21  2291.378906  11919927.0      9   17        3
# 20  2317.096191  15668979.0      9   16        2
# 22  2298.306396  15264068.0      9   18        4
# 17  2312.311523  27445768.0      9   11        4
# 19  2311.414551  12542824.0      9   15        1
# 23  2248.616455  15519031.0      9   21        0
# 40  2199.424561   9246702.0     10   15        3
# 39  2280.164795  12341434.0     10   14        2
# 24  2204.059570  16056620.0      9   22        1

# %% [markdown]
# So the highest opening value was 2360 which was in the month of September.

# %% [markdown]
# # Inferences and Conclusion
# In this notebook, i tried to analyse the data of Reliance Stocks 2020 which is my favourite topics personally. So i thought why not analyse one of the stocks of share market. I took help from the zero to pandas course provided from Jovian.ml, also pandas library and matplotlib,seaborn. This was my first analysing project and by doing this i am gettig a confidence to do more projects. I learned lot about the reliance stocks its highs, lows, opening prize, closing prize. I got lots of information from this dataset.

# %% [markdown]
# # References and Future Work
# https://www.pandas.pydata.org, https://www.kaggle.com/, https://jovian.ai/outlink?url=https%3A%2F%2Fjovian.ml%2Fforum%2Ft%2Frecommended-datasets-for-course-project%2F11711
